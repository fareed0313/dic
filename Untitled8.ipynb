# %%
my_list = [10, 20, 30, 40, 50]


last_element = my_list[-1]
second_last_element = my_list[-2]

print(f"Last element: {last_element}")
print(f"Second to last element: {second_last_element}")
print(my_list[-3])
print(my_list[-4])
print(my_list[-5])
# Out:
# Last element: 50
# Second to last element: 40
# 30
# 20
# 10

# %%
t = [1, 2, 3]
del t[0]
letters = ['a', 'b', 'c', 'd', 'e']
del letters[0], letters[3]
print(letters)
# Out:
# ['b', 'c', 'd']

# %%
def delete_head(t):
  del t[0]
  letters = ['a', 'b', 'c', ]
  delete_head(letters)
  print(letters)

# %%
a = {1: 'fareed' , 2: 'zameer'}
print(a)
# Out:
# {1: 'fareed', 2: 'zameer'}

# %%
b = {}
b[1] = 'fareed'
b[2] = 'zameer'
b[3] = 'aasim'
print(b)
# Out:
# {1: 'fareed', 2: 'zameer', 3: 'aasim'}

# %%
c = {}
c[1] = 'its show time'
c[2] = 'zameer'
c[3] = 'lets go '
print(c)
# Out:
# {1: 'its show time', 2: 'zameer', 3: 'lets go '}
